# %% [markdown]
# # Getting data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import warnings
from ML_utils import *
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('processminer-rare-event-mts.xlsx')

# %%
df.head()
# Out:
#                  time  y        x1        x2        x3         x4        x5  \
# 0 1999-05-01 00:00:00  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830
# 1 1999-05-01 00:02:00  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733
# 2 1999-05-01 00:04:00  0  0.363848 -4.681394 -4.353147  14.127997 -0.138636
# 3 1999-05-01 00:06:00  0  0.301590 -4.758934 -4.023612  13.161566 -0.148142
# 4 1999-05-01 00:08:00  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314
#
#           x6        x7        x8  ...        x52       x53       x54  \
# 0 -20.669883  0.000732 -0.061114  ...  10.091721  0.053279 -4.936434
# 1 -18.758079  0.000732 -0.061114  ...  10.095871  0.062801 -4.937179
# 2 -17.836632  0.010803 -0.061114  ...  10.100265  0.072322 -4.937924
# 3 -18.517601  0.002075 -0.061114  ...  10.104660  0.081600 -4.938669
# 4 -17.505913  0.000732 -0.061114  ...  10.109054  0.091121 -4.939414
#
#          x55        x56       x57       x58       x59       x60  x61
# 0 -24.590146  18.515436  3.473400  0.033444  0.953219  0.006076    0
# 1 -32.413266  22.760065  2.682933  0.033536  1.090502  0.006083    0
# 2 -34.183774  27.004663  3.537487  0.033629  1.840540  0.006090    0
# 3 -35.954281  21.672449  3.986095  0.033721  2.554880  0.006097    0
# 4 -37.724789  21.907251  3.601573  0.033777  1.410494  0.006105    0
#
# [5 rows x 63 columns]

# %%
df['y'].value_counts()
# Out:
# 0    18274
# 1      124
# Name: y, dtype: int64

# %%
df.isna().any().value_counts()
# Out:
# False    63
# dtype: int64

# %%
#Separating df's for features and target
dtrainx=df.drop(['time','y'],axis=1)
dtrainy=df['y']
#preparing data for CV
X=df.drop(['time','y'],axis=1).values
y=df['y'].values

# %%
#Pipeline com normalizacao e classificador 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import tree

pip = Pipeline([('std',StandardScaler()),('clf',tree.DecisionTreeClassifier())])

# %% [markdown]
# # CV with several classifiers

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

clfs = []
clfs.append(LogisticRegression())
clfs.append(SVC())
clfs.append(KNeighborsClassifier(n_neighbors=3))
clfs.append(DecisionTreeClassifier())
clfs.append(RandomForestClassifier())
clfs.append(GradientBoostingClassifier())

# %%
#Doing CV for all clasiifiers in the above
cv=Cross_valid_clf(X,y,n_splits=5)
for classifier in clfs:
    print("-"*100)
    print(str(classifier))
    pip.set_params(clf = classifier)
    cv.score(pip)
# Out:
# ----------------------------------------------------------------------------------------------------
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# ------------------------------
#
# Fold 1 out of 5
# Accuracy_score: 0.8190217391304347
# ------------------------------
#
# Fold 2 out of 5
# Accuracy_score: 0.9942934782608696
# ------------------------------
#
# Fold 3 out of 5
# Accuracy_score: 0.8692934782608696
# ------------------------------
#
# Fold 4 out of 5
# Accuracy_score: 0.9051630434782608
# ------------------------------
#
# Fold 5 out of 5
# Accuracy_score: 0.967373572593801
#
#  Overall Score:
# Accuracy_score Mean: 0.911029062344847   Std: 0.06379542847929794
# ----------------------------------------------------------------------------------------------------
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
# ------------------------------
#
# Fold 1 out of 5
# Accuracy_score: 0.7293478260869565
# ------------------------------
#
# Fold 2 out of 5
# Accuracy_score: 0.9940217391304348
# ------------------------------
#
# Fold 3 out of 5
# Accuracy_score: 0.9942934782608696
# ------------------------------
#
# Fold 4 out of 5
# Accuracy_score: 0.9932065217391305
# ------------------------------
#
# Fold 5 out of 5
# Accuracy_score: 0.8575312669929309
#
#  Overall Score:
# Accuracy_score Mean: 0.9136801664420645   Std: 0.10621565434662826
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')
# ------------------------------
#
# Fold 1 out of 5
# Accuracy_score: 0.7040760869565217
# ------------------------------
#
# Fold 2 out of 5
# Accuracy_score: 0.9934782608695653
# ------------------------------
#
# Fold 3 out of 5
# Accuracy_score: 0.9942934782608696
# ------------------------------
#
# Fold 4 out of 5
# Accuracy_score: 0.9945652173913043
# ------------------------------
#
# Fold 5 out of 5
# Accuracy_score: 0.8548123980424144
#
#  Overall Score:
# Accuracy_score Mean: 0.908245088304135   Std: 0.1154644683919923
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ------------------------------
#
# Fold 1 out of 5
# Accuracy_score: 0.6252717391304348
# ------------------------------
#
# Fold 2 out of 5
# Accuracy_score: 0.8902173913043478
# ------------------------------
#
# Fold 3 out of 5
# Accuracy_score: 0.9820652173913044
# ------------------------------
#
# Fold 4 out of 5
# Accuracy_score: 0.9951086956521739
# ------------------------------
#
# Fold 5 out of 5
# Accuracy_score: 0.7014681892332789
#
#  Overall Score:
# Accuracy_score Mean: 0.8388262465423079   Std: 0.1497033199185968
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ------------------------------
#
# Fold 1 out of 5
# Accuracy_score: 0.9451086956521739
# ------------------------------
#
# Fold 2 out of 5
# Accuracy_score: 0.9951086956521739
# ------------------------------
#
# Fold 3 out of 5
# Accuracy_score: 0.9951086956521739
# ------------------------------
#
# Fold 4 out of 5
# Accuracy_score: 0.9932065217391305
# ------------------------------
#
# Fold 5 out of 5
# Accuracy_score: 0.9771615008156607
#
#  Overall Score:
# Accuracy_score Mean: 0.9811388219022625   Std: 0.01923503680866204
# ----------------------------------------------------------------------------------------------------
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# ------------------------------
#
# Fold 1 out of 5
# Accuracy_score: 0.35081521739130433
# ------------------------------
#
# Fold 2 out of 5
# Accuracy_score: 0.8179347826086957
# ------------------------------
#
# Fold 3 out of 5
# Accuracy_score: 0.9951086956521739
# ------------------------------
#
# Fold 4 out of 5
# Accuracy_score: 0.9945652173913043
# ------------------------------
#
# Fold 5 out of 5
# Accuracy_score: 0.9382816748232735
#
#  Overall Score:
# Accuracy_score Mean: 0.8193411175733504   Std: 0.24300744010793549

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(dtrainx,dtrainy,test_size=0.20,random_state=0)
feature_importance_plot(algorithm=RandomForestClassifier(),X_train=x_train,y_train=y_train,of_type="feat")
